# %% [markdown]
# # 聚类
#
#
# ## 载入相应模块

# %%
import re
import json
from sklearn.cluster import KMeans,MiniBatchKMeans,AffinityPropagation,MeanShift,SpectralClustering,AgglomerativeClustering,DBSCAN
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer as ss
import jieba
from sklearn import feature_extraction  
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.cluster import normalized_mutual_info_score as NMI
from sklearn.mixture import GaussianMixture

# %%
stp = stopwords.words('english')
stm = ss('english')

# %% [markdown]
# ## 处理tweet文件 构造text和label的list

# %%
d=open('Tweets2.txt','r+')
text=[]
label=[]
texts=d.readlines()
for i in texts:
    text.append(json.loads(i)["text"])
    label.append(json.loads(i)["cluster"])
print(text[:10])
print(min(label))
# Out:
# ['brain fluid buildup delay giffords rehab', 'trailer talk week movie rite mechanic week opportunity', 'rnc appoints chairman tampa convention effort visit tampa republican nati tampa fl', 'gbagbo camp futile cut ivory coast economy', 'chinese president lost translation powerful leader meet expect tran', 'england fishing community current management system broken edf', 'protest reform start yemen hundred anti government protester gathered sanaa', 'stuxnet lead chernobyl russian', 'iphone share smartphones phone', 'uploaded youtube video nba final lakers celtic game memory highlig']
# 1

# %%
text2=[]

for i in text:
    s=i.split()
    print(s)
    z=[]
    for word in s:
        word = stm.stem(word)
        z.append(word)

    text2.append(z)
print(text2[1000:1002])
# Out:
# ['brain', 'fluid', 'buildup', 'delay', 'giffords', 'rehab']
# ['trailer', 'talk', 'week', 'movie', 'rite', 'mechanic', 'week', 'opportunity']
# ['rnc', 'appoints', 'chairman', 'tampa', 'convention', 'effort', 'visit', 'tampa', 'republican', 'nati', 'tampa', 'fl']
# ['gbagbo', 'camp', 'futile', 'cut', 'ivory', 'coast', 'economy']
# ['chinese', 'president', 'lost', 'translation', 'powerful', 'leader', 'meet', 'expect', 'tran']
# ['england', 'fishing', 'community', 'current', 'management', 'system', 'broken', 'edf']
# ['protest', 'reform', 'start', 'yemen', 'hundred', 'anti', 'government', 'protester', 'gathered', 'sanaa']
# ['stuxnet', 'lead', 'chernobyl', 'russian']
# ['iphone', 'share', 'smartphones', 'phone']
# ['uploaded', 'youtube', 'video', 'nba', 'final', 'lakers', 'celtic', 'game', 'memory', 'highlig']
# ['feed', 'epic', 'sci', 'fi', 'car', 'ad', 'kia', 'optimum', 'super', 'bowl', 'commercial', 'video', 'trendhunter', 'supe']
# ['naughty', 'facebook', 'started', 'sharing', 'personal', 'detail', 'site', 'day', 'turn', 'fb']
# ['super', 'bowl', 'commercial']
# ['bruce', 'will', 'fave', 'kardashian', 'lol']
# ['attack', 'journalist', 'escalate', 'egypt']
# ['keith', 'olbermann', 'join', 'current', 'tv', 'report']
# ['opinion', 'christina', 'sounded', 'amazing', 'super', 'bowl', 'america', 'making', 'big', 'deal']
# ['sundance', 'day', 'strange', 'celebrity', 'encounter', 'steve', 'carell', 'elijah', 'wood', 'full', 'day', 'sundanc']
# ['acai', 'berry', 'supplement', 'weight', 'loss', 'associated', 'content', 'heard', 'oprah', 'win']
# ['finished', 'watching', 'black', 'swan', 'twisted', 'mental', 'strain', 'take', 'embrace', 'role', 'natalie', 'portman', 'incredible']
# ['hot', 'air', 'breaking', 'rahm', 'ballot', 'tcot', 'lt', 'state', 'totally', 'corrupt']
# ['charlie', 'sheen', 'abuse']
# ['music', 'featured', 'motorola', 'xoom', 'super', 'bowl', 'commercial']
# ['rite', 'movie', 'review', 'fan', 'movie', 'deal', 'battle', 'good', 'evil']
# ['potential', 'replacement', 'steve', 'job']
# ['yemen', 'president', 'signal', 'won', 'stay', 'freedomwar', 'egypt', 'jan', 'syria', 'feb']
# ['debt', 'settlement', 'lawyer', 'debt', 'settlement', 'easier', 'lawyer', 'day', 'debt', 'settlement', 'beco']
# ['aguilera', 'repeat', 'national', 'anthem', 'ap', 'ap', 'christina', 'aguilera', 'flubbed', 'belted']
# ['skipped', 'romanian', 'crew', 'journalist', 'threatened', 'attacked', 'detained', 'reporting', 'egypt']
# ['loss', 'weight', 'acai', 'berry', 'capsule', 'benefit']
# ['pew', 'internet', 'online', 'american', 'social', 'networking', 'twitter', 'politics', 'campaign', 'internet']
# ['tbf', 'flw', 'outdooors', 'introduce', 'national', 'high', 'school', 'fishing', 'program', 'national', 'high', 'school', 'fishing', 'program']
# ['fucking', 'awesome', 'jesse', 'jesse', 'ventura', 'slam', 'tsa', 'lawsuit']
# ['king', 'speech', 'awarded', 'best', 'ensemble', 'cast', 'screen', 'actor', 'guild', 'award']
# ['charge', 'fee', 'saltwater', 'fishing', 'license']
# ['bottega', 'veneta', 'teal', 'turquoise', 'knot', 'intrecciato', 'snakeskin', 'clutch']
# ['baked', 'slow', 'cooker', 'chicken', 'crockpotrecipes']
# ['fake', 'snow', 'storm', 'white', 'stripe', 'officially', 'call', 'quits']
# ['chrysler', 'air', 'super', 'bowl', 'commercial']
# ['kid', 'set', 'college', 'time', 'fill', 'fafsa']
# ['funny', 'happened', 'aguilera', 'repeat', 'national', 'anthem', 'yahoo', 'news']
# ['hollywood', 'director', 'honor', 'king', 'speech', 'reuters']
# ['kung', 'pao', 'chicken', 'recipe']
# ['giffords', 'rocky', 'road', 'recovery', 'health', 'news']
# ['complete', 'list', 'super', 'bowl', 'commercial', 'advertiser', 'youtube']
# ['senator', 'avoiding', 'tea', 'party', 'caucus']
# ['watch', 'volkswagen', 'superbowl', 'commercial', 'youtube', 'ad', 'blitz', 'channel', 'escarabaajoos']
# ['washington', 'legislature', 'wade', 'immigration', 'debate', 'oregonlive', 'summary', 'requires', 'employe', 'verify']
# ['te', 'boozing', 'news', 'starbucks', 'huge', 'trenta', 'cup', 'hold', 'entire', 'bottle', 'wine']
# ['carney', 'obama', 'press', 'secretary']
# ['kardashians', 'pier', 'morgan', 'stupid', 'answer', 'question', 'perfect']
# ['chavez', 'mark', 'year', 'office', 'venezuelan', 'president', 'hugo', 'chavez', 'mark', 'year', 'power', 'promising', 'press']
# ['rite', 'safe', 'horror', 'film', 'devil', 'time', 'plain', 'dealer']
# ['chipotle', 'fire', 'hundred', 'immigration', 'raid', 'immigration', 'probe', 'forced', 'mexican', 'chain', 'chipotle', 'fire']
# ['beetle', 'commercial', 'creative', 'superbowl', 'great', 'teaser']
# ['yemen', 'thousand', 'protest', 'government', 'worldnomads', 'travelsafety']
# ['going', 'amazing', 'constitutional', 'showdown', 'reach', 'supreme', 'court']
# ['aquarium', 'fish', 'aquarium', 'success', 'good', 'common', 'sense', 'will', 'fir']
# ['justice', 'extend', 'protection', 'workplace', 'retaliation', 'supreme', 'court', 'ruled', 'employer', 'sued']
# ['white', 'house', 'press', 'secretary', 'jay', 'carney']
# ['oscar', 'reaction', 'guess', 'king', 'speech']
# ['cnn', 'hack', 'facebook', 'unlocks', 'security', 'facebook', 'adding', 'security', 'feature', 'pa']
# ['nfl', 'concussion', 'people', 'survey', 'wix', 'jsquared', 'concussion']
# ['national', 'guard', 'called', 'chicago', 'snow', 'storm', 'woow', 'snow', 'chill', 'people']
# ['loooooooooooove', 'ncis']
# ['weight', 'loss', 'diet', 'plan', 'acai', 'juice', 'equal', 'nutritional', 'claim', 'acai']
# ['traffic', 'depot', 'update', 'oceanside', 'green', 'light', 'red', 'light', 'camera', 'ticket', 'traffic']
# ['christina', 'aguilera', 'mess', 'national', 'anthem', 'start', 'super', 'bowl', 'xlv']
# ['definitely', 'forward', 'superbowl', 'commercial', 'year', 'esp', 'steve', 'martin', 'cameo']
# ['acai', 'berry', 'diet', 'succeed', 'hoodia', 'gordonii', 'site', 'acai', 'berry', 'cultivated', 'acai', 'palm']
# ['hugo', 'chavez', 'apologizes', 'venezuelan', 'people', 'ahead', 'election']
# ['fishing', 'news', 'banner', 'website']
# ['keith', 'olbermann', 'join', 'current', 'tv', 'report', 'keith', 'olbermann', 'controversial', 'liberal', 'pundit', 'ho']
# ['chicago', 'rahm', 'emanuel', 'ballot']
# ['tanning', 'iced', 'coffee', 'tazo', 'iced', 'tea', 'hello', 'trenta']
# ['watching', 'kourtney', 'kim', 'khloe', 'loving', 'waiting', 'forever']
# ['vincent', 'tabak', 'appears', 'court', 'charged', 'murder']
# ['casserole', 'recipe', 'bruschetta', 'chicken', 'bake', 'submitted', 'heather', 'simple', 'creative', 'chicken', 'meal', 'mimic']
# ['honor', 'epic', 'fail', 'national', 'anthem', 'top', 'ten', 'list', 'time', 'worst']
# ['info', 'topic', 'fish', 'tank', 'heater', 'aquarium', 'stuff', 'technorati', 'tag', 'aquarium', 'heater', 'aquariu']
# ['grilled', 'chicken', 'tomato', 'salad']
# ['today', 'read', 'concerned', 'gasland', 'movie', 'stand', 'set', 'record', 'straight']
# ['king', 'speech', 'top', 'film', 'producer', 'award', 'ap', 'ap', 'king', 'speech', 'claimed', 'crown', 'be']
# ['sag', 'prediction', 'award', 'tracker', 'hmmmm']
# ['kia', 'spent', 'lot', 'money', 'optimum', 'superbowl', 'commercial']
# ['doritos', 'commercial', 'raising', 'dead', 'best', 'night', 'superbowl', 'nfl']
# ['idf', 'intelligence', 'chief', 'iran', 'nuclear', 'bomb', 'year', 'haaretz']
# ['yeah', 'don', 'csis', 'nciss', 'enjoy', 'mentalist']
# ['uk', 'robert', 'kubica', 'injured', 'rally', 'accident', 'italian', 'polish', 'medium']
# ['breaking', 'news', 'king', 'speech', 'take', 'top', 'honor', 'hollywood', 'actor', 'honor', 'best', 'sunday', 'night', 'annual', 'screen', 'ac']
# ['obamacare', 'reagan', 'appointed', 'federal', 'district', 'judge', 'florida', 'ruled', 'key', 'portion', 'obama']
# ['st', 'tunisia', 'egypt', 'yemen']
# ['best', 'superbowl', 'commercial', 'year', 'chrysler', 'comeback']
# ['horrible', 'journalist', 'attacked', 'detained', 'egypt', 'yahoo', 'news']
# ['list', 'journalist', 'hurt', 'harassed', 'egypt']
# ['famous', 'facebook', 'flip', 'flop', 'social', 'networking', 'goliath', 'number', 'hasty', 'move', 'year']
# ['yikes', 'list', 'journalist', 'attacked', 'egypt', 'hour', 'abc', 'news']
# ['lady', 'press', 'ahead', 'fitness', 'campaign', 'daily', 'caller', 'obama', 'tell', 'abc', 'good', 'morning', 'america']
# ['judge', 'rule', 'obama', 'health', 'care', 'law']
# ['watch', 'christina', 'aguilera', 'screw', 'national', 'anthem', 'super', 'bowl', 'post']
# ['acai', 'berry', 'powder', 'content', 'health', 'weight', 'loss', 'hard', 'figure']
# ['facebook', 'privacy', 'setting', 'user']
# ['taco', 'bell', 'beef', 'convenience', 'cost']
# ['jordan', 'thousand', 'protest', 'demand', 'pm', 'step', 'wave', 'mass', 'protest', 'arab', 'spread', 'opposition', 'supporter']
# ['yap', 'palau', 'sport', 'fishing', 'promotional', 'sport', 'fishing', 'video', 'produced', 'video', 'rating']
# ['court', 'third', 'party', 'bias', 'protection', 'broad', 'washington', 'jan', 'upi', 'supreme', 'court', 'ruled', 'unanimously']
# ['yell', 'cast', 'jr', 'hartley', 'ad', 'digital', 'era', 'author', 'search', 'fly', 'fishing', 'book', 'dj', 'hunt', 'book', 'read']
# ['boatsshopping', 'fishing', 'headline', 'oklahoma', 'metro', 'trout', 'fishing', 'pond', 'instructional', 'clinic', 'pave', 'exciting', 'winter', 'angling', 'html']
# ['three', 'ton', 'striped', 'bass', 'seized', 'illegal', 'fishing', 'net']
# ['federal', 'judge', 'strike', 'health', 'care', 'reform', 'call', 'insurance', 'purchase', 'mandate', 'aba', 'journal']
# ['love', 'khloe', 'kardashian']
# ['fighter', 'king', 'speech', 'lead', 'nominee', 'tonight', 'sag', 'award', 'beverly', 'hill', 'courier']
# ['check', 'video', 'christina', 'aguilera', 'super', 'bowl', 'national', 'anthem', 'mistake', 'mess', 'err']
# ['murray', 'djokovic', 'happened']
# ['pressure', 'grows', 'myanmar', 'sanction', 'call', 'growing', 'western', 'sanction', 'myanmar']
# ['poll', 'gop', 'catch', 'dems', 'social', 'medium']
# ['nobel', 'war', 'prize', 'wikileaks', 'nuke', 'fired', 'cablegate', 'wikileaks', 'assange', 'anonymous']
# ['bbc', 'news', 'police', 'lose', 'officer']
# ['lololol', 'doritos', 'pepsi', 'max', 'killing', 'superbowl', 'commercial']
# ['federal', 'judge', 'healthcare', 'law']
# ['king', 'speech', 'notch', 'top', 'director', 'award', 'movie', 'running', 'darren', 'aronofsky']
# ['yummy', 'recipe', 'tuesday', 'chicken', 'fricasse']
# ['secret', 'natural', 'weight', 'loss', 'food', 'acai', 'berry', 'benefit']
# ['job', 'wrong', 'place', 'memo', 'president', 'dear', 'president', 'state', 'union', 'add']
# ['employment', 'gaining', 'speed', 'jobless', 'rate']
# ['ten', 'thousand', 'yemeni', 'protest', 'sanaa', 'ten', 'thousand', 'yemeni', 'staged', 'day', 'rage', 'calling']
# ['awful', 'watched', 'don', 'text', 'drive', 'video', 'driving', 'class']
# ['netgear', 'bos', 'astonishing', 'attack', 'steve', 'job']
# ['bronco', 'christina', 'aguilera', 'flub', 'national', 'anthem', 'kmgh', 'denver']
# ['governor', 'proposes', 'sweeping', 'cut', 'funding', 'york', 'school', 'medicaid', 'program', 'slashed']
# ['check', 'article', 'fox', 'news', 'sideline', 'test', 'detect', 'concussion', 'minute']
# ['eye', 'will', 'definetely', 'glued', 'tv', 'screen', 'love', 'kardashians']
# ['don', 'text', 'drive', 'pledge']
# ['fishing', 'technique', 'fishing', 'maine', 'surf', 'fishing', 'striped', 'bass']
# ['tsa', 'unveils', 'body', 'scanner', 'software', 'doesn', 'naked', 'alternet']
# ['oscar', 'king', 'speech', 'haven', 'black', 'swan']
# ['teen', 'creates', 'anti', 'bullying', 'school', 'program']
# ['bedbug', 'rapidly', 'evolving', 'fight', 'pesticide', 'tech', 'news']
# ['super', 'bowl', 'commercial', 'report', 'card', 'ranking', 'winner', 'loser', 'bleacher', 'report']
# ['fast', 'food', 'caught', 'immigration', 'crosshairs', 'reuters']
# ['vice', 'president', 'communication', 'director', 'jay', 'carney', 'named', 'white', 'house', 'press', 'secretary']
# ['high', 'court', 'third', 'party', 'sue', 'retaliation', 'case']
# ['kold', 'aguilera', 'repeat', 'national', 'anthem']
# ['volkswagon', 'commercial', 'superbowl']
# ['deadbedbugs', 'fact', 'bed', 'bug', 'cover']
# ['gross', 'taco', 'bell', 'sued', 'bogus', 'beef']
# ['great', 'bbc', 'piece', 'summarising', 'unrest', 'north', 'africa', 'middle', 'east']
# ['sidney', 'crosby', 'concussion', 'rule', 'change', 'braine', 'hope', 'pray', 'doesn', 'sight']
# ['charlie', 'sheen', 'leaf', 'hospital', 'medical', 'emergency']
# ['trenta', 'cup', 'hold', 'entire', 'bottle', 'wine', 'wrong']
# ['healthy', 'school', 'food', 'pay', 'save', 'attention', 'going']
# ['post', 'financial', 'aid', 'college', 'lt', 'gt', 'financial', 'advice', 'lt', 'gt', 'popular', 'lt', 'gt', 'lt', 'gt']
# ['teacher', 'talking', 'texting', 'driving', 'haaayy']
# ['financial', 'aid', 'help', 'woman', 'school', 'hispanic', 'scholarship']
# ['mubarak', 'silencing', 'voice', 'egypt', 'journalist', 'targeted', 'read', 'jan', 'tahrir']
# ['video', 'favorite', 'superbowl', 'commercial', 'cute']
# ['remember', 'alex', 'brown']
# ['enjoyed', 'vw', 'beetle', 'commercial', 'superbowl', 'favorite']
# ['join', 'campaign', 'texting', 'driving', 'save', 'life', 'future', 'will', 'help']
# ['crazy', 'lake', 'shore', 'drive', 'downtown', 'chicago', 'shut']
# ['blog', 'post', 'potential', 'replacement', 'steve', 'job', 'apple']
# ['acai', 'berry', 'chocolate', 'tasting', 'weight', 'loss', 'diet', 'plan', 'adi', 'news', 'scientifically', 'prov']
# ['red', 'cabbage', 'add', 'color', 'noodle', 'salad', 'soba', 'salad', 'chicken', 'cabbage']
# ['boosting', 'america', 'fashion']
# ['news', 'workshop', 'preventing', 'bullying', 'positive', 'behavior', 'support', 'school']
# ['yemen', 'president', 'won', 'election']
# ['best', 'buy', 'launch', 'electronics', 'buy', 'program', 'ap', 'ap', 'timing', 'shopping', 'gadget']
# ['force', 'strong', 'great', 'ad', 'volkswagon', 'superbowl', 'commercial']
# ['dragon', 'cute', 'drinking', 'cola', 'superbowl', 'cocacola', 'commercial']
# ['latest', 'headline', 'king', 'speech', 'lead', 'oscar', 'field', 'british', 'star', 'colin', 'firth', 'helena', 'bonham', 'carter', 'nominate']
# ['klassy', 'breeze', 'music', 'blog', 'black', 'eyed', 'aguilera', 'love']
# ['journalist', 'social', 'medium', 'report', 'egyptian', 'demonstration', 'journalist']
# ['hooper', 'earns', 'top', 'dga', 'prize', 'king', 'speech', 'hooper', 'won', 'david', 'fincher', 'social', 'network']
# ['ap', 'maker', 'academy', 'award', 'favorite', 'social', 'network', 'king', 'speech', 'competi']
# ['congrats', 'novak', 'djokovic', 'played', 'brilliant', 'tennis', 'definitely', 'deserve', 'title']
# ['breaknews', 'yemen', 'street', 'day', 'rage', 'yemeni', 'filled', 'street', 'sanaa']
# ['protest', 'start', 'yemen', 'despite', 'concession', 'president', 'hundred', 'anti', 'government', 'protest']
# ['al', 'jazeera', 'journalist', 'detained', 'cairo', 'police', 'hotel', 'room', 'equipment', 'confiscated', 'jan']
# ['update', 'michael', 'steele', 'resigns', 'rnc']
# ['egypt', 'yemen', 'demand', 'change', 'government', 'well', 'gt', 'news', 'tcot']
# ['orange', 'student', 'dish', 'school', 'lunch', 'white', 'house', 'chef', 'orlando', 'sentinel', 'fl', 'schoollunch', 'letsmove']
# ['successful', 'ice', 'fishing', 'perch', 'depth', 'finder', 'successful', 'ice']
# ['acai', 'berry', 'weight', 'loss', 'diet', 'plan', 'healthy', 'weight', 'reduction', 'number', 'diet', 'plan']
# ['thought', 'beef', 'lawsuit', 'pr', 'response']
# ['chris', 'hemsworth', 'lead', 'celebrity', 'storm', 'tao', 'sundance', 'ministry', 'appreciates', 'sundance', 'film', 'festival', 'founder']
# ['chipotle', 'face', 'ice', 'inspection', 'state', 'reuters', 'reuters', 'chipotle', 'mexican', 'grill']
# ['love', 'kim', 'kardashian', 'ur', 'hot', 'wooohoooo', 'lol']
# ['ten', 'thousand', 'march', 'yemen', 'president', 'sanaa', 'yemen', 'ten', 'thousand', 'lukewilliamss']
# ['best', 'commercial', 'super', 'bowl', 'imported', 'detroit', 'best']
# ['late', 'night', 'time', 'watch', 'crime', 'solving', 'tv', 'ncis', 'csi', 'sky', 'looooove']
# ['doritos', 'commercial', 'vote', 'funniest', 'superbowl', 'commercial']
# ['budweiser', 'wild', 'west', 'tiny', 'dancer', 'commercial', 'definitely', 'favorite', 'superbowl']
# ['best', 'deal', 'fishing', 'bait', 'lure', 'ebay', 'best', 'price']
# ['fallon', 'follow', 'tip', 'save', 'energy', 'included', 'site', 'tip', 'will', 'help', 'beat', 'hig']
# ['uk', 'foreign', 'office', 'urgently', 'checking', 'briton', 'caught', 'explosion', 'uk', 'news']
# ['government', 'spending', 'cut', 'leave', 'north', 'east', 'forestry', 'commission', 'base', 'saveourforests']
# ['starbucks', 'trenta', 'hold', 'entire', 'bottle', 'wine', 'people', 'cougartown']
# ['interested', 'giffords', 'improves', 'watch', 'hour', 'tv', 'gabrielle', 'giffords', 'watched', 'hour', 'television']
# ['doc', 'river', 'll', 'wait', 'chris', 'forsberg', 'boston', 'celtic', 'captain', 'paul', 'pierce', 'departed', 'thursday']
# ['facebook', 'privacy', 'setting', 'user']
# ['daily', 'review', 'murdoch', 'ipad', 'newspaper', 'rupert', 'murdoch', 'ipad', 'launch', 'daily', 'offer', 'glitzy', 'graphic']
# ['commercial', 'video', 'eminem', 'lipton', 'brisk', 'super', 'bowl', 'commercial']
# ['updated', 'rehab', 'aim', 'giffords', 'life']
# ['breakingnews', 'looter', 'broke', 'museum', 'destroyed', 'pharaonic', 'mummy', 'late', 'friday', 'nation', 'top', 'archaeologist', 'reuters', 'egypt']
# ['grant', 'fishing', 'smile', 'set', 'grant', 'arizona', 'game', 'fish', 'department', 'ki']
# ['tech', 'cnn', 'hack', 'facebook', 'unlocks', 'security', 'facebook', 'adding', 'security', 'feature']
# ['black', 'swan', 'amazing', 'natalie', 'portman', 'deserves', 'award', 'doubt', 'will']
# ['recipe', 'chicken', 'cutlet']
# ['favorited', 'youtube', 'video', 'gm', 'chevy', 'super', 'bowl', 'commercial', 'bumblebee']
# ['thousand', 'protest', 'jordan', 'middle', 'east']
# ['sundance', 'today', 'tobey', 'maguire', 'demi', 'moore', 'kate', 'bosworth', 'tobey', 'maguire', 'waitin']
# ['extraordinary', 'stuff', 'arrested', 'beaten', 'egypt', 'police']
# ['florida', 'top', 'freshwater', 'fishing', 'destination']
# ['best', 'fly', 'fishing', 'website']
# ['weight', 'loss', 'diet', 'plan', 'living', 'healthy', 'acai', 'berry', 'adi', 'news', 'acai', 'berry', 'promote', 'weight', 'loss', 'imp']
# ['super', 'bowl', 'commercial']
# ['asia', 'center', 'graduate', 'summer', 'grant', 'harvard', 'university', 'usa', 'beasiswa', 'scholarship']
# ['yemen', 'girds', 'day', 'rage', 'saleh', 'vow', 'step', 'bloomberg']
# ['king', 'speech', 'lead', 'academy', 'award', 'nomination', 'including', 'best', 'picture']
# ['freemont', 'tribune', 'safety', 'tip', 'atm', 'tip', 'safety']
# ['man', 'charged', 'joanna', 'yeates', 'murder']
# ['internet', 'news', 'steve', 'job', 'medical', 'problem', 'affect', 'apple', 'stock', 'latest', 'internet', 'news', 'steve', 'job']
# ['gop', 'voter', 'active', 'social', 'networking', 'site', 'political', 'purpose', 'washing', 'artimpactnetpr']
# ['obama', 'campaign', 'playbook', 'promote', 'agenda', 'social', 'medium']
# ['don', 'text', 'drive', 'makeachange']
# ['yemen', 'arrest', 'anti', 'government', 'activist', 'yemen']
# ['king', 'speech', 'win', 'top', 'honor', 'director', 'guild', 'award']
# ['mobile', 'market', 'grew', 'smartphones', 'android', 'driver', 'will', 'drive', 'marke']
# ['fishing', 'report', 'fishnotes', 'caught', 'bass', 'gofishn']
# ['uk', 'news', 'lady', 'take', 'campaign', 'childhood', 'obesity', 'army', 'base']
# ['watch', 'rite', 'free', 'movie', 'online', 'movie', 'online']
# ['fly', 'box', 'folly', 'north', 'american', 'fly', 'fishing', 'forum', 'ongoing', 'effort', 'achieve', 'system', 'perfection']
# ['king', 'speech', 'dominates', 'sag', 'award', 'win', 'best', 'picture', 'osacrs', 'sagawards', 'thekingsspeech']
# ['arizona', 'bid', 'block', 'citizenship', 'illegal', 'immigrant', 'anchor', 'baby', 'tcot', 'tlot']
# ['acai', 'berry', 'diet', 'sexy', 'acai', 'berry', 'scam', 'warning', 'acai', 'berry', 'diet']
# ['lmao', 'didn', 'feistyoldpeople', 'chevy', 'commercial', 'superbowl']
# ['mouratoglou', 'murray', 'djokovic', 'classic', 'yahoo']
# ['endsmeat', 'christina', 'aguilera', 'mess', 'lyric', 'national', 'anthem', 'super', 'bowl']
# ['wilmington', 'nc', 'inshore', 'winter', 'fishing', 'report']
# ['oscar', 'nomination', 'full', 'list', 'academy', 'award', 'nominee']
# ['indicator', 'point', 'great', 'fall', 'steelhead', 'fishing']
# ['yemen', 'protest', 'intensify', 'arrest', 'journalist', 'tawakkol', 'karman']
# ['rash', 'report', 'social', 'medium', 'tool', 'social', 'unrest', 'john', 'rash', 'tunisian', 'mohamed', 'bouazizi', 'cou']
# ['commerce', 'bos', 'immigration', 'reform']
# ['acai', 'berry', 'diet', 'side', 'effect', 'lose', 'weight', 'fast', 'acai', 'berry', 'diet', 'side', 'effe']
# ['great', 'win', 'packer', 'christina', 'land', 'blunder']
# ['celebrity', 'gossip', 'fishing', 'madison', 'river', 'montana']
# ['conan', 'blast', 'christina', 'super', 'bowl', 'anthem', 'blunder', 'time']
# ['identity', 'theft', 'cost', 'create', 'problem', 'business', 'deal', 'reaching', 'fake', 'provider', 'showz']
# ['florida', 'judge', 'strike', 'obamacare', 'america']
# ['king', 'speech', 'rule', 'obvious', 'batch', 'oscar', 'bait', 'news', 'cnews', 'canada']
# ['check', 'price', 'fly', 'fishing', 'lure', 'ebay', 'store', 'info']
# ['debt', 'consolidation', 'help', 'avoid', 'bankruptcy', 'debt', 'consolidation', 'involves', 'single', 'loan']
# ['acai', 'berry', 'acai', 'berry', 'juice', 'weight', 'loss']
# ['daddy', 'prefers', 'vw', 'commercial', 'messing', 'mini', 'darth', 'superbowl', 'dadstalking']
# ['slow', 'news', 'day', 'chicago', 'll', 'live', 'bloggin', 'mayoral', 'debate', 'cdt']
# ['super', 'bowl', 'commercial', 'coca', 'cola', 'commercial', 'coke']
# ['wished', 'looked', 'lucy', 'hale', 'kourtney', 'kardashian', 'pretty']
# ['reuters', 'celebs', 'hollywood', 'actor', 'honor', 'king', 'speech', 'los', 'angeles', 'reuters', 'oscar', 'front', 'runner', 'king']
# ['best', 'recipe', 'caesar', 'salad', 'caesarsalad']
# ['school', 'tackling', 'cut', 'teen', 'concussion', 'bull', 'ring', 'drill', 'football']
# ['reason', 'acai', 'berry', 'weight', 'loss', 'diet', 'case', 'half', 'popula']
# ['court', 'allows', 'emanuel', 'ballot', 'chicago', 'mayor', 'nytimes', 'tlot', 'news', 'illinois', 'dems']
# ['trout', 'steelhead', 'fly', 'fishing', 'supply', 'stretched', 'canvas', 'poster', 'steelhead', 'trout', 'image']
# ['fatal', 'blast', 'reported', 'moscow', 'airport', 'terminal', 'russian', 'authority', 'monday', 'reported', 'fatal', 'explosion']
# ['simple', 'easy', 'prepare', 'vintage', 'fried', 'chicken', 'recipe']
# ['huffingtonpost', 'sundance', 'film', 'festival', 'james', 'franco', 'three', 'company', 'installation']
# ['australia', 'flooding', 'cost', 'enormous']
# ['win', 'djokovic', 'won', 'australian', 'open']
# ['cnn', 'killed', 'injured', 'terror', 'blast', 'moscow', 'airport', 'terrorist', 'suicide', 'bomber', 'blamed', 'mosco']
# ['fishing', 'bait', 'bait', 'trout', 'fishing', 'trout', 'fishing', 'type', 'equipment', 'dictate']
# ['actress', 'farmiga', 'sundance', 'directing', 'debut', 'reuters', 'reuters', 'vera', 'farmiga', 'big', 'breakout']
# ['dc', 'medium', 'opt', 'tea', 'party', 'tea', 'party', 'caucus', 'remains', 'vigilant', 'teaparty', 'tcot', 'tlot', 'gop', 'dem']
# ['youtube', 'video', 'eminem', 'lipton', 'brisk', 'super', 'bowl', 'commercial']
# ['jordan', 'protester', 'gather', 'country', 'demanding', 'prime', 'minister', 'step', 'al', 'jazeera']
# ['credit', 'card', 'debt', 'consolidation', 'gt', 'credit', 'card', 'studentloans', 'info', 'conso']
# ['sow', 'bug', 'round', 'north', 'american', 'fly', 'fishing', 'forum', 'time', 'march', 'mountain']
# ['meat', 'high', 'quality', 'mediapost', 'beef', 'brouhaha', 'taco', 'bell', 'buzz', 'suffering', 'mediapost']
# ['clinton', 'bugun', 'misir', 'hk', 'nededi', 'secretary', 'clinton', 'condemns', 'attack', 'demonstrator', 'journalist', 'egypt', 'vide', 'jan']
# ['weight', 'loss', 'diet', 'plan', 'south', 'american', 'acai', 'berry', 'currently', 'american', 'lose']
# ['acai', 'berry', 'weight', 'loss', 'diet', 'plan', 'healthy', 'weight', 'reduction']
# ['missouri', 'court', 'rule', 'immigrant', 'adoption', 'right', 'terminated', 'illegally', 'missouri', 'supreme', 'court', 'tuesday', 'ove']
# ['king', 'speech', 'usurps', 'throne', 'oscar', 'leader', 'ap']
# ['coming', 'airport', 'modesty', 'change']
# ['super', 'bowl', 'national', 'anthem', 'singer', 'christina', 'aguilera', 'fail', 'video']
# ['chrysler', 'telling', 'story', 'well', 'check', 'chrysler', 'commercial', 'imported', 'detroit']
# ['top', 'story', 'illinois', 'supreme', 'court', 'rahm', 'emanuel', 'ballot', 'illinois', 'supreme', 'court', 'issued', 'ruling']
# ['weight', 'loss', 'diet', 'acai', 'berry', 'weight', 'loss', 'diet', 'plan', 'diet', 'diet', 'food', 'weight', 'loss', 'beauty', 'sally', 'beauty', 'bea']
# ['entent', 'complete', 'list', 'nomination', 'annual', 'academy', 'award']
# ['hella', 'funnny', 'drt', 'superbowl', 'funniest', 'doritos', 'commercial']
# ['undergraduate', 'scholarship', 'international', 'college', 'hotel', 'management', 'australia', 'beasiswa', 'schola']
# ['hott', 'cold', 'sundance', 'film', 'festival', 'lola', 'blog']
# ['discus', 'fish', 'aquarium']
# ['netherlands', 'recall', 'iran', 'ambassador', 'dutch', 'woman', 'execution', 'foreign', 'policy', 'outrage']
# ['video', 'volkswagen', 'invades', 'super', 'bowl', 'darth', 'vader', 'starwars', 'superbowl']
# ['best', 'buy', 'launch', 'electronics', 'buy', 'program']
# ['workshop', 'offer', 'help', 'student', 'aid', 'form', 'regional', 'workshop', 'open', 'help', 'faf']
# ['drive', 'text']
# ['heard', 'acai', 'berry', 'diet', 'acai', 'berry', 'heard', 'diet', 'purchasing']
# ['continuing', 'cooking', 'winning', 'streak', 'awesome', 'lemon', 'fennel', 'pot', 'roast', 'chicken', 'chicken', 'boring']
# ['red', 'fishing', 'knot', 'book', 'book', 'fishing', 'harry']
# ['wikileaks', 'pushed', 'uk', 'sanction', 'iranian', 'bank', 'cable', 'view', 'britain', 'settin', 'jpost']
# ['king', 'speech', 'wint', 'twee', 'screen', 'actor', 'guild', 'award']
# ['beck', 'rating', 'plummeted']
# ['aaron', 'rodgers', 'helmet', 'saved', 'concussion', 'bear', 'green', 'bay', 'packer', 'qb', 'aaron', 'rodgers', 'believ']
# ['don', 'text', 'drive']
# ['aguilera', 'repeat', 'national', 'anthem']
# ['facebook', 'privacy', 'setting', 'user']
# ['watching', 'superbowl', 'darth', 'vader', 'commercial', 'awesome', 'love', 'dude']
# ['ncis', 'stupidest', 'fucking', 'television']
# ['international', 'scholarship', 'bangor', 'university', 'uk', 'beasiswa', 'scholarship']
# ['fish', 'eat', 'complete', 'fishing', 'guide']
# ['live', 'state', 'massachusetts', 'financial', 'aid', 'college']
# ['bbc', 'yemeni', 'rally', 'president', 'thousand', 'yemeni', 'demonstrating', 'capital', 'sanaa', 'calling', 'president', 'ali', 'abdullah']
# ['applying', 'financial', 'aid', 'groundless', 'myth']
# ['dutch', 'government', 'end', 'official', 'contact', 'iran', 'protest', 'hanging', 'dutch', 'iranian', 'woman', 'al', 'jazeera']
# ['reporting', 'arrest', 'journalist', 'cairo']
# ['rnc', 'money', 'ronald', 'reagan', 'birthday']
# ['charlottesville', 'city', 'school', 'offering', 'student', 'vegetarian', 'option', 'lunch']
# ['prettyman', 'annual', 'fish', 'porn', 'provider', 'coming', 'fly', 'fishing', 'film', 'festival', 'bring', 'subject', 'called']
# ['three', 'journalist', 'tf', 'detained', 'cairo', 'jan', 'mubarak', 'egypt', 'egipto', 'fb']
# ['egypt', 'ripple', 'ally', 'yemeni', 'prez', 'ali', 'abdullah', 'saleh', 'power', 'year', 'won', 'seek', 'term']
# ['eastern', 'sport', 'outdoor', 'harrisburg', 'hunting', 'fishing', 'idea', 'marcus', 'schneck', 'patrio']
# ['don', 'care', 'starbucks', 'trenta', 'cup', 'bigger', 'stomach']
# ['al', 'jazeera', 'report', 'region', 'yemen', 'pres', 'extend', 'term', 'protest', 'call', 'syria']
# ['revolt', 'contagious', 'anti', 'government', 'protest', 'spread', 'yemen', 'tcot', 'tlot', 'jan', 'sidibouzid']
# ['american', 'fishing', 'book', 'guide', 'value']
# ['king', 'speech', 'win', 'big', 'dgas', 'award', 'season', 'tight', 'race', 'social', 'network']
# ['vw', 'black', 'beetle', 'commercial', 'favorite', 'super', 'bowl', 'ad', 'night']
# ['canadian', 'journalist', 'detained', 'harassed', 'foreign', 'journalist', 'targeted', 'cairo']
# ['sidney', 'crosby', 'concussion', 'raise', 'safety', 'debate', 'hockey', 'spark', 'discussion']
# ['omg', 'oprah', 'plege', 'wouldn', 'text', 'drive', 'didn', 'seriously', 'lol', 'xd', 'bbl']
# ['wlcentral', 'yemen', 'day', 'rage', 'february', 'egypt', 'jan', 'yemen', 'feb']
# ['law', 'suit', 'taco', 'bell', 'beef', 'filler', 'find', 'taco', 'bell', 'chihuahua']
# ['chipotle', 'caught', 'immigration', 'crosshairs', 'yahoo', 'news', 'knew', 'genuine', 'mexican', 'working']
# ['love', 'kardashian', 'doll', 'fave', 'doll', 'khloe', 'gt']
# ['elizabeth', 'olsen', 'sundance', 'film', 'festival', 'debut', 'sister', 'footstep', 'theatrical']
# ['screen', 'actor', 'guild', 'award', 'list', 'winner', 'sag', 'king', 'speech', 'reign', 'supreme', 'edie', 'falco']
# ['facebook', 'finally', 'offer', 'http', 'change', 'setting']
# ['competitive', 'fishing', 'tactic', 'fly', 'everyday', 'fisherman', 'thinking', 'man']
# ['creamy', 'recipe', 'fettuccine', 'alfredo', 'chicken', 'recipe']
# ['ice', 'fishing', 'bro', 'brohsdahl', 'jason', 'mitchell', 'byron', 'eckhardt', 'special', 'ice', 'fishing', 'schtick']
# ['flyfishing', 'big', 'earth', 'publishing', 'flyfishing', 'barry', 'reynolds', 'bass', 'walleye', 'buy', 'john']
# ['interview', 'venezuela', 'sweetheart', 'champion', 'chavez', 'venezuelan', 'president', 'hugo', 'chavez', 'speaks', 'meeting']
# ['court', 'emanuel', 'eligible', 'chicago', 'mayor', 'ny', 'time', 'pa', 'habit', 'sur', 'place', 'assez', 'longtemps']
# ['jay', 'carney', 'white', 'house', 'press', 'secretary', 'richard', 'adam', 'guardian']
# ['king', 'speech', 'top', 'screen', 'actor', 'guild', 'award', 'winner', 'mtv', 'movie', 'music']
# ['insurance', 'news', 'federal', 'judge', 'reject', 'health', 'reform', 'law', 'district', 'court', 'judge', 'roger', 'vinson', 'agreed']
# ['attorney', 'general', 'office', 'identity', 'theft', 'prevention', 'tip', 'west', 'virginia', 'attorney', 'general', 'darrell', 'mcgraw']
# ['duraflame', 'log', 'beef', 'taco', 'bell']
# ['superbowl', 'volkswagen', 'commercial', 'force']
# ['hilarious', 'super', 'bowl', 'commercial']
# ['web', 'daily', 'stunning', 'slow', 'day', 'launch', 'daily', 'ipad', 'newspaper', 'ipad']
# ['sundance', 'familiar', 'territory', 'elizabeth', 'bank', 'omg']
# ['hellothere', 'king', 'speech', 'win', 'sag', 'award', 'king', 'speech', 'win', 'best', 'actor', 'trophy', 'sunday', 'bythere']
# ['reporter', 'attacked', 'attack', 'journalist', 'send', 'message']
# ['case', 'haven', 'brilliant', 'motorola', 'xoom', 'ad', 'super', 'bowl']
# ['justin', 'bieber', 'address', 'danger', 'texting', 'driving', 'extreme', 'makeover', 'music', 'celebrity', 'justin', 'bieber']
# ['fda', 'approved', 'injectable', 'drug', 'called', 'makena', 'reduce', 'risk', 'preterm', 'delivery', 'week']
# ['yemeni', 'president', 'ruled', 'decade', 'll', 'seek', 'extend', 'term', 'pas', 'power', 'son', 'reuters']
# ['brytec', 'fly', 'fishing', 'box', 'brytec', 'fishing']
# ['aquarium', 'fish', 'basic', 'plant', 'container', 'garden', 'pl']
# ['school', 'tackling', 'cut', 'teen', 'concussion']
# ['dont', 'text', 'drive']
# ['thousand', 'jordan', 'protest', 'demand', 'pm', 'step', 'day', 'protest', 'opposition', 'supporter', 'stre']
# ['novak', 'djokovic', 'win', 'australian', 'open', 'well', 'deserved', 'played', 'amazing', 'couldn', 'help', 'feel', 'andy', 'murray']
# ['bad', 'best', 'commercial', 'movie', 'trailer', 'random', 'urge', 'buy', 'doritos', 'bud', 'light', 'superbowl']
# ['type', 'identity', 'theft', 'dark', 'dragon', 'grownup', 'identity', 'theft']
# ['guided', 'fly', 'fishing', 'muskegon', 'river', 'trout']
# ['love', 'khloe', 'alexandra', 'kardashian', 'biggest', 'fan', 'kuwait', 'will', 'meet']
# ['king', 'speech', 'rule', 'obvious', 'batch', 'oscar', 'bait', 'ap']
# ['recap', 'steve', 'job', 'will', 'good', 'time', 'apple']
# ['gt', 'annual', 'academy', 'award', 'nomination', 'announced', 'man', 've', 'best', 'picture', 'noms']
# ['today', 'stock', 'market', 'dow', 'jones', 'industrial', 'average', 'dji', 'nasdaq']
# ['doctor', 'giffords', 'face', 'rocky', 'road', 'recovery', 'day', 'week', 'rep', 'gabrielle', 'giffords', 'recovery']
# ['france', 'fox', 'piven', 'defies', 'death', 'threat', 'taunt', 'anchorman', 'glenn', 'beck', 'mental']
# ['reuters', 'top', 'news', 'yemen', 'president', 'won', 'extend', 'term', 'pas', 'son']
# ['oscar', 'nominated', 'gasland', 'director', 'josh', 'fox', 'gas', 'drilling', 'barnett', 'shale', 'dallas', 'observer', 'blog']
# ['full', 'video', 'super', 'bowl', 'national', 'anthem', 'singer', 'christina', 'aguilera', 'fail', 'imalive']
# ['political', 'power', 'social', 'medium', 'foreign', 'affair']
# ['identity', 'theft', 'steal', 'social', 'security', 'number', 'theft']
# ['complete', 'book', 'fly', 'fishing']
# ['college', 'best', 'financial', 'aid', 'arizona', 'state', 'university']
# ['spreading', 'thousand', 'protest', 'jordan', 'demand', 'pm', 'step', 'aljazeera', 'net']
# ['manchester', 'austerity', 'cut', 'hit', 'frontline', 'service', 'leisure', 'centre', 'library', 'swimming', 'pool', 'public', 'toile']
# ['thing', 'social', 'medium', 'revolution']
# ['best', 'buy', 'launch', 'electronics', 'buy', 'program', 'ap']
# ['social', 'network', 'king', 'speech', 'aim', 'oscar', 'ap', 'ap', 'academy', 'award', 'voter', 'poised', 'set', 'showd']
# ['ticker', 'thousand', 'yemeni', 'call', 'president', 'quit']
# ['australian', 'open', 'final', 'novak', 'djokovic', 'andy', 'murray', 'live', 'blog', 'bleacher', 'report', 'contributor', 'scott']
# ['yemen', 'republican', 'guard', 'dispatched', 'roaming', 'street', 'sana', 'reliable', 'source']
# ['cbc', 'ticker', 'southeast', 'australia', 'brace', 'flood', 'australia', 'deadly', 'flood', 'crisis', 'forced', 'people']
# ['fda', 'approves', 'pharma', 'preterm', 'birth', 'drug', 'embattled', 'drugmaker', 'pharmaceutical', 'reported', 'health', 'reg']
# ['acai', 'berry', 'weight', 'loss', 'confusing', 'helen', 'arsenault', 'january', 'talk', 'mogul', 'op']
# ['update', 'fly', 'fishing', 'tip', 'beginner', 'ultimate', 'guide', 'learn', 'fly', 'fish', 'pro']
# ['ufo', 'paranormal', 'terrorist', 'bombing', 'moscow', 'airport']
# ['hawaii', 'won', 'release', 'obama', 'birth', 'info']
# ['horse', 'racing', 'oc', 'tavern', 'bar', 'state', 'offer', 'track', 'horse', 'betting']
# ['starbucks', 'size', 'trente', 'hold', 'entire', 'bottle', 'wine', 'enjoy']
# ['super', 'bowl', 'recipe', 'todd', 'dirt', 'dirt', 'man', 'shared', 'recipe', 'patch', 've', 'ta']
# ['spicy', 'food', 'popular', 'child', 'quick', 'thai', 'style', 'chicken', 'soup', 'will', 'hit']
# ['crystal', 'clear', 'kim', 'kardashian', 'single', 'fucking', 'idiot']
# ['drug', 'rehab', 'work', 'charlie', 'sheen', 'reportedly', 'receiving', 'help', 'clearest', 'benefit', 'pat']
# ['social', 'network', 'king', 'speech', 'aim', 'oscar', 'ap', 'ap', 'academy', 'award', 'voter', 'poised', 'set']
# ['real', 'acai', 'berry', 'supplement', 'deal', 'rapid', 'fast', 'weight', 'loss', 'well', 'ordered', 'acai', 'berry', 'blast']
# ['watching', 'extreme', 'makeover', 'don', 'text', 'drive']
# ['gotta', 'luv', 'video', 'jesse', 'ventura', 'strike', 'lawsuit', 'tsa']
# ['acai', 'berry', 'social', 'bookmarking', 'net', 'acai', 'berry', 'latest', 'weight', 'loss', 'buy', 'acai', 'berry', 'best', 'colon', 'cleanse']
# ['worst', 'best', 'super', 'bowl', 'commercial', 'video']
# ['st', 'andrew', 'st', 'michael', 'school', 'hold', 'second', 'annual', 'bullying', 'awareness', 'conference']
# ['supreme', 'court', 'temporarily', 'halt', 'georgia', 'execution']
# ['acai', 'berry', 'powder', 'ehow', 'acai', 'berry', 'powder', 'acai', 'berry', 'extraordinarily']
# ['chicken', 'vegetable', 'herb', 'brown', 'rice']
# ['egypt', 'military', 'secures', 'famed', 'antiquity', 'museum']
# ['completely', 'freaky', 'sense', 'sony', 'xperia', 'play', 'commercial', 'kind', 'awesome', 'creepy', 'thumb', 'superbowl']
# ['love', 'coke', 'commercial', 'dragon', 'superbowl']
# ['al', 'jazeera', 'thousand', 'egyptian', 'youth', 'form', 'human', 'shield', 'protect', 'egyptian', 'museum', 'museum', 'egypt', 'jan']
# ['tceltics', 'davis', 'leaf', 'game', 'sun', 'sore', 'hamstring', 'boston', 'celtic', 'nbanewsfeed']
# ['street', 'yemen', 'day', 'rage', 'sanaa', 'reuters', 'yemeni']
# ['rahm', 'emanuel', 'ballot', 'chicago', 'alternet']
# ['judge', 'rule', 'health', 'care', 'law', 'foxnews']
# ['fishing', 'striped', 'bass', 'll', 'fight', 'hard', 'fish', 'pull', 'force', 'lake', 'norman', 'st']
# ['charlie', 'rating', 'soar', 'big', 'bonus', 'short', 'rehab']
# ['cash', 'college', 'workshop', 'tomorrow', 'find', 'location']
# ['audi', 'super', 'bowl', 'commercial', 'online', 'video', 'audi']
# ['fishing', 'report', 'jan', 'illinois', 'winter', 'steelhead', 'fishing', 'good', 'driftboaters', 'cop']
# ['patrick', 'asks', 'obama', 'intervene', 'fishing', 'regulation', 'dispute']
# ['expert', 'differ', 'sanction', 'debate']
# ['chipotle', 'face', 'ice', 'inspection', 'state', 'reuters']
# ['skinny', 'burn', 'fat']
# ['walmart', 'embrace', 'lady', 'nutrition', 'campaign']
# ['fishing', 'rapala', 'original', 'floater', 'fishing', 'lure', 'original', 'floating', 'rapala', 'fished', 'fishingkahuna']
# ['super', 'bowl', 'prediction', 'volkswagen', 'commercial', 'force', 'beat', 'audi', 'goodnight', 'commercial', 'seo']
# ['autism', 'awareness', 'month', 'education', 'key', 'bully']
# ['rioter', 'destroy', 'mummy', 'egyptian', 'museum', 'cairo', 'filed', 'art', 'culture', 'history', 'learning', 'afric']
# ['bottega', 'veneta', 'rtw', 'spring', 'beautiful', 'fashion', 'art', 'gt']
# ['mainenance', 'fishing', 'rod', 'preserving', 'rod', 'read']
# ['lt', 'gt', 'acai', 'berry', 'lt', 'gt', 'weight', 'loss', 'side', 'effect', 'improvement']
# ['blizzard', 'break', 'chicago', 'snow', 'record', 'inch', 'expected']
# ['suicide', 'bomber', 'blamed', 'moscow', 'airport', 'attack', 'killed', 'russian', 'state', 'tv', 'report']
# ['save', 'text', 'save', 'life', 'don', 'text', 'driving', 'text', 'life', 'imagine', 'dream', 'inspire']
# ['ford', 'paid', 'shit', 'load', 'commercial', 'air', 'time', 'superbowl']
# ['smart', 'money', 'future', 'mixed', 'ahead', 'data', 'earnings', 'market', 'update', 'stock', 'future', 'mi', 'investing', 'money']
# ['starbucks', 'terrifying', 'trenta', 'cup', 'hold', 'entire', 'bottle', 'wine']
# ['msn', 'today', 'joanna', 'yeates', 'suspect', 'court']
# ['illinois', 'state', 'appeal', 'court', 'declared', 'rahm', 'emanuel', 'ineligible', 'mayor', 'chicago', 'born', 'kenya']
# ['exactly', 'acai', 'berry', 'diet', 'pill', 'wrk', 'yahoo', 'answer', 'acai', 'berry', 'diet', 'pill']
# ['buck', 'belief', 'nba', 'concussion', 'protocol', 'three', 'year', 'ago', 'ucla', 'luc', 'richard', 'mbah', 'moute', 'sust']
# ['tip', 'help', 'reduce', 'energy', 'bill', 'control', 'electricity', 'save', 'money', 'power', 'bill']
# ['breaking', 'news', 'fluid', 'buildup', 'rep', 'giffords', 'brain', 'will', 'delay', 'start', 'full', 'fledged', 'rehabilitation', 'hou']
# ['toledo', 'bend', 'report', 'chicken', 'coop', 'providing', 'hot', 'crappie', 'action', 'love', 'bass', 'fishing', 'bu']
# ['rid', 'bedbug']
# ['favorite', 'superbowl', 'motorola', 'xoom', 'tablet', 'swipe', 'apple', 'tonight']
# ['awesome', 'bold', 'superbowl', 'commercial', 'seriously', 'going', 'consider', 'xoom', 'tablet', 'ipad']
# ['identity', 'theft', 'cost', 'infographic']
# ['tip', 'fly', 'fishing', 'brook', 'trout', 'stream', 'manual', 'angler', 'ten', 'tip', 'fly']
# ['sixth', 'annual', 'avnet', 'tech', 'game', 'offer', 'scholarship', 'networking', 'opportunity', 'winning', 'student', 'will']
# ['dorritos', 'pepsi', 'commercial', 'tyrant', 'superbowl', 'commercial']
# ['rite', 'movie', 'review', 'fan', 'movie', 'deal', 'battle', 'good']
# ['gang', 'hunt', 'journalist', 'right', 'worker', 'egypt', 'nytimes', 'jatkhs']
# ['kardashians', 'episode', 'good']
# ['social', 'medium', 'blast', 'christina', 'aguilera', 'national', 'anthem', 'super', 'bowl', 'flub', 'day', 'social', 'medium']
# ['sinfully', 'spicy', 'easy', 'easy', 'eat', 'reshmi', 'chicken', 'kebab', 'roll', 'indianfood', 'recipe', 'indianfastfood']
# ['identity', 'theft', 'cost', 'infographic', 'online', 'fraud', 'crime', 'rise', 'mo']
# ['commercial', 'motorola', 'xoom', 'suck', 'people', 'apple', 'tool', 'sb', 'superbowl']
# ['white', 'stripe', 'breaking', 'performance', 'record', 'winnipeg', 'free', 'press']
# ['mercedes', 'benz', 'class', 'coupe', 'sl', 'amg', 'roadster', 'revealed', 'superbowl', 'commercial', 'tmr']
# ['murray', 'congratulation', 'djokovic', 'winning', 'men', 'australianopen', 'championship', 'nice', 'work', 'going', 'bed']
# ['portman', 'firth', 'speech', 'win', 'sag', 'award', 'los', 'angeles', 'jan', 'upi', 'star', 'king', 'speech', 'ho']
# ['police', 'open', 'fire', 'yemen', 'protester', 'sanaa', 'yemen', 'ap', 'witness', 'police', 'opened', 'fire', 'break']
# ['variety', 'freshwater', 'aquarium', 'fish']
# ['save', 'poptarts', 'tmr', 'chicago', 'foot', 'snow', 'hour', 'forecaster']
# ['rnc', 'best', 'shot', 'knocking', 'debt', 'time', 'race', 'leading', 'pack']
# ['pound', 'test', 'bass', 'fishing', 'rod', 'yahoo', 'answer']
# ['watched', 'solid', 'acting', 'anthony', 'hopkins', 'sr', 'beauty', 'alice', 'braga', 'rite', 'view']
# ['acai', 'berry', 'weight', 'loss', 'diet', 'plan', 'healthy', 'weight', 'reduction', 'number', 'diet', 'plan']
# ['master', 'phd', 'scholarship', 'university', 'manitoba', 'canada', 'beasiswa', 'scholarship']
# ['best', 'worm', 'bait', 'fishing', 'thom', 'conroy', 'helium']
# ['acai', 'berry', 'work', 'lose', 'weight', 'lose', 'weight', 'heard', 'acai', 'berry', 'pe']
# ['journalist', 'targeted', 'pro', 'mubarak', 'force', 'egypt', 'video']
# ['bbc', 'news', 'king', 'speech', 'lead', 'oscar', 'field']
# ['student', 'juvenile', 'arthritis', 'apply', 'college', 'scholarship', 'staff', 'report', 'arthritis', 'foundation']
# ['love', 'ncis', 'arc', 'outcome', 'funeral']
# ['leon', 'payn', 'bottega', 'veneta', 'coming']
# ['egypt', 'protest', 'gauntlet', 'officer', 'beating', 'stick']
# ['yemen', 'president', 'quit', 'february', 'updated']
# ['suicide', 'bomber', 'kill', 'moscow', 'airport', 'explosion', 'ripped', 'interna', 'lukewilliamss']
# ['starbucks', 'trenta', 'cup', 'hold', 'entire', 'bottle', 'wine', 'random', 'starbucks', 'trenta', 'college']
# ['vincent', 'tabak', 'man', 'accused', 'jo', 'yeates', 'murder', 'deeply', 'saddened', 'death', 'telegraph']
# ['florida', 'judge', 'declares', 'entire', 'healthcare', 'law', 'void', 'month', 'half', 'ago', 'virginia', 'judge', 'key', 'pr']
# ['motorola', 'xoom', 'super', 'bowl', 'commercial', 'tip', 'hat', 'apple', 'spot', 'video']
# ['fly', 'fishing', 'magazine', 'guide']
# ['cost', 'financial', 'aid', 'chicago', 'school', 'professional', 'psychology']
# ['eminem', 'brisk', 'super', 'bowl', 'commercial']
# ['american', 'journalist', 'bloodied', 'detained', 'egyptian', 'force', 'dozen', 'foreign', 'journalist', 'egypt', 'attac']
# ['gallery', 'celebrity', 'sighting', 'sundance', 'film', 'festival']
# ['whycollegenow', 'present', 'college', 'scholarship', 'fantastic', 'post', 'college', 'scholar']
# ['ll', 'sporting', 'mine', 'will', 'mac', 'wednesday', 'february', 'anti', 'bullying', 'day']
# ['identity', 'theft', 'cost', 'infographic', 'long', 'ago', 'identity', 'theft', 'online']
# ['favorite', 'thing', 'chicken', 'breast']
# ['glenn', 'beck', 'rating', 'year', 'ago', 'fb']
# ['judge', 'strike', 'healthcare', 'reform', 'law']
# ['tsa', 'body', 'scanner', 'spot', 'bomb', 'dong', 'tsa']
# ['boston', 'celtic', 'jermaine', 'neal', 'arthroscopic', 'knee', 'surgery', 'recovery', 'period', 'week', 'espn', 'nba']
# ['video', 'terror', 'texting', 'toronto', 'gta', 'news', 'toronto', 'sun']
# ['weight', 'loss', 'diet', 'plan', 'living', 'healthy', 'acai', 'berry', 'adi', 'news', 'acai', 'berry', 'promote', 'weight', 'loss', 'imp']
# ['fishing', 'ski', 'report', 'detroit', 'free', 'press', 'ice', 'fishing', 'continues', 'heavy', 'snow', 'will', 'travel']
# ['nut', 'war', 'medium', 'continues', 'al', 'jazeera', 'journalist', 'arrested', 'cairo', 'camera', 'equipment', 'seized', 'egypt', 'jan', 'aljazeera']
# ['best', 'buy', 'future', 'proof', 'tech', 'purchase', 'buy', 'program', 'cost', 'istockanalyst', 'press', 'release']
# ['james', 'franco', 'platinum', 'blonde', 'hilarious', 'jac']
# ['obsession', 'gt', 'ncis']
# ['egyptian', 'military', 'rounding', 'journalist', 'egypt', 'pm', 'issue', 'apology', 'star', 'egypt', 'live', 'blog', 'jan']
# ['full', 'list', 'nominee', 'official', 'oscar', 'website']
# ['phife', 'dawg', 'atcq', 'speaking', 'sundance', 'film', 'festival', 'video']
# ['caught', 'lb', 'pike', 'flick', 'fishing', 'flickfishing']
# ['right', 'group', 'claim', 'chavez', 'judiciary', 'foe']
# ['vote', 'favorite', 'superbowl', 'commercial', 'poll', 'don', 'love']
# ['march', 'yemen', 'president', 'day', 'rage']
# ['car', 'commercial', 'boring', 'volkswagon', 'enjoyed', 'superbowl', 'spot']
# ['option', 'credit', 'card', 'debt', 'consolidation', 'loan']
# ['didn', 'doritos', 'commercial', 'boring', 'superbowl']
# ['pcworld', 'android', 'tablet', 'smartphone', 'boost', 'samsung']
# ['film', 'rite', 'based', 'training', 'real', 'priest', 'film', 'faith', 'catholic', 'exorcist']
# ['consumerist', 'tsa', 'testing', 'revealing', 'full', 'body', 'scanner', 'software']
# ['star', 'head', 'sundance']
# ['hillary', 'clinton', 'egypt', 'state', 'hillary', 'clinton', 'treatment', 'journalist', 'coveri']
# ['news', 'day', 'starbucks', 'trenta', 'cup', 'hold', 'entire', 'bottle', 'wine']
# ['live', 'tweet', 'taco', 'bell', 'claim', 'meat', 'beef', 'wasn', 'typo']
# ['giffords', 'condition', 'upgraded', 'good']
# ['social', 'medium', 'tool', 'protest', 'middle', 'east', 'police', 'worst']
# ['pack', 'vw', 'superbowl', 'darth', 'vader', 'commercial', 'easily', 'best', 'well', 'vw']
# ['best', 'buy', 'target', 'launch', 'buy', 'electronics', 'offer', 'currently', 'rachel', 'blog', 'travel', 'industry', 'news']
# ['motorward', 'kia', 'optimum', 'epic', 'ride', 'super', 'bowl', 'commercial']
# ['celebrity', 'sighting', 'sundance', 'film', 'festival']
# ['protest', 'erupt', 'yemen']
# ['indian', 'navy', 'arrest', 'pirate', 'drama', 'high', 'sea', 'major', 'anti', 'piracy', 'operation']
# ['yemeni', 'president', 'ali', 'abdullah', 'saleh', 'will', 'seek', 'extend', 'presidency', 'appoint', 'son', 'role', 'current']
# ['pesto', 'presto', 'chicken', 'pesto', 'presto', 'chicken', 'feel', 'good', 'favorite', 'cozy', 'meal', 'famil']
# ['russia', 'stuxnet', 'caused', 'chernobyl', 'david', 'brunnstrom', 'reuters', 'david', 'brunnstrom', 'reuters', 'rus']
# ['political', 'power', 'social', 'medium', 'foreign', 'affair']
# ['iran', 'executes', 'iranian', 'dutch', 'woman']
# ['best', 'buy', 'launch', 'electronics', 'buy', 'program', 'timing', 'shopping', 'gadget', 'socialmedia']
# ['thousand', 'protest', 'yemen']
# ['acai', 'berry', 'juice', 'diet', 'regime', 'operate', 'excess', 'weight', 'heading', 'answer', 'question', 'soo']
# ['christina', 'aguilera', 'flubbed', 'national', 'anthem', 'lost', 'moment', 'bw']
# ['artsbeat', 'christina', 'aguilera', 'flub', 'national', 'anthem', 'nytimes', 'share', 'friend', 'art', 'classical', 'musi']
# ['king', 'speech', 'garnered', 'oscar', 'nomination', 'assuring', 'hollywood', 'handful', 'general', 'public', 'watched', 'movie']
# ['protest', 'protect', 'human', 'history', 'human', 'wall', 'protecting', 'cairo', 'museum', 'egypt', 'egypte', 'egipto', 'mubarak', 'pls']
# ['love', 'shirt', 'store', 'ncis']
# ['audi', 'commercial', 'best', 'superbowl']
# ['love', 'reali', 'kardashian', 'saludos', 'mexico']
# ['superbowl', 'ad', 'ehhhh', 'doritos', 'funny', 'lame', 'brandbowl']
# ['loved', 'sense', 'humor', 'article', 'help', 'bully', 'proofing', 'child', 'gt']
# ['mama', 'favorite', 'easy', 'chicken', 'pasta', 'mother', 'knew', 'food', 'knew', 'hand']
# ['hit', 'em', 'kenny', 'love', 'audi', 'commercial', 'superbowl']
# ['annual', 'academy', 'award', 'nomination', 'announced', 'film']
# ['djokovic', 'longer', 'slam', 'wonder', 'novak', 'djokovic', 'enjoyed', 'crushing', 'australian', 'open', 'final', 'triumph', 'andy', 'murray']
# ['beef', 'beef', 'law', 'firm', 'sue', 'taco', 'bell', 'false', 'advertising', 'cattle']
# ['best', 'buy', 'launch', 'electronics', 'buy', 'program', 'timing', 'shopping', 'gadget']
# ['volkswagen', 'star', 'war', 'commercial', 'dominates', 'super', 'bowl', 'twitter', 'buzz']
# ['day', 'bloody', 'clash', 'egypt', 'foreign', 'journalist', 'arrested']
# ['oscar', 'race', 'speed', 'sag', 'award', 'news']
# ['federal', 'judge', 'rule', 'health', 'care', 'law', 'violates', 'constitution', 'nacsonline']
# ...
# ['identity', 'theft', 'cost', 'comment']
# ['film', 'king', 'speech', 'win', 'producer', 'guild', 'top', 'prize', 'los', 'angeles', 'king', 'speech', 'claimed', 'crown']
# ['straight', 'catwalk', 'stan', 'jouk']
# ['head', 'mossad', 'week', 'ago', 'stuxnet', 'set', 'iranian', 'nuke', 'plan', 'decade', 'fox', 'news', 'iran', 'nuke', 'yr']
# ['thing', 'private', 'scholarship', 'college', 'solution', 'usnews']
# ['carnage', 'bomber', 'target', 'moscow', 'airport']
# ['protect', 'phishing', 'scam']
# ['natalie', 'portman', 'modern', 'family', 'king', 'speech', 'crowned', 'sag', 'winner']
# ['gothic', 'abby', 'cbs']
# ['chicago', 'blizzard', 'closed', 'lake', 'shore', 'drive', 'entire', 'length', 'notice']
# ['south', 'indian', 'river', 'february', 'fishing', 'forecast']
# ['top', 'weight', 'loss', 'pill', 'include', 'acai', 'berry', 'purchased']
# ['arizona', 'bid', 'block', 'citizenship', 'illegal', 'immigrant', 'anchor', 'baby']
# ['black', 'swan', 'tonight', 'amazing', 'natalie', 'portman', 'talented', 'actress', 'bestmovieever', 'blackswan', 'lt']
# ['blog', 'post', 'farm', 'fresh', 'recipe', 'idea', 'easy', 'chicken', 'wing', 'week', 'farm', 'fresh', 'recipe', 'idea', 'geared', 'towar']
# ['republican', 'gain', 'democrat', 'social', 'medium', 'study', 'released', 'pew', 'center', 'internet']
# ['acai', 'berry', 'weight', 'loss', 'formula', 'program', 'flush', 'pound', 'lose', 'weight', 'free', 'bottle']
# ['commercial', 'superbowl', 'beer', 'doritos', 'car']
# ['king', 'speech', 'crowned', 'head', 'oscar', 'nominee', 'colin', 'firthphoto', 'afpbritish', 'historical', 'drama', 'king', 'speech']
# ['apple', 'steve', 'job', 'newsweek']
# ['hear', 'christina', 'aguilera', 'mangled', 'star', 'spangled', 'banner', 'superbowl', 'twilight', 'reaming']
# ['platypus', 'dead', 'illegal', 'fishing', 'net', 'animal', 'environment', 'fishing']
# ['wired', 'legendary', 'steve', 'job', 'leave', 'absence', 'medical', 'reason', 'second', 'time']
# ['florida', 'judge', 'rule', 'obamacare']
# ['spartan', 'newsletter', 'spartan', 'fishing', 'team', 'ihsa', 'bass', 'fishing', 'high']
# ['protect', 'internet']
# ['catch', 'janelle', 'monae', 'prince', 'msg', 'unreal', 'sundance', 'sexytime', 'park', 'city']
# ['fishing', 'relaxing', 'rejuvenating', 'sport', 'fishing', 'relaxing', 'sport', 'solo']
# ['black', 'swan', 'night', 'london', 'masterpiece', 'portman', 'oscar']
# ['man', 'hour', 'judge', 'vinson', 'obamacare', 'second', 'ruling']
# ['love', 'kourtney', 'kardashian']
# ['dinner', 'idea', 'dinner', 'recipe', 'easy', 'weekly', 'meal', 'plan', 'check', 'going']
# ['levelled', 'fishing', 'levelled', 'fishing', 'skill', 'level', 'runescape']
# ['cressi', 'spear', 'fishing', 'america', 'black', 'snork', 'america', 'black', 'cressi']
# ['chrysler', 'air', 'super', 'bowl', 'commercial']
# ['tip', 'fishing', 'salmon', 'alaska']
# ['sun', 'man', 'charged', 'killing', 'jo', 'yeates', 'police', 'tonight', 'charged', 'year', 'vincent', 'tabac', 'murder']
# ['aquarium', 'fish', 'handbook', 'tropical', 'aquarium', 'fish', 'handbook', 'tropical', 'aquarium', 'fish', 'book', 'discus', 'bree']
# ['middle', 'east', 'news', 'ten', 'thousand', 'fill', 'yemen', 'street', 'day', 'rage', 'haaretz', 'follow']
# ['youtube', 'video', 'brisk', 'eminem', 'super', 'bowl', 'commercial']
# ['check', 'article', 'fox', 'news', 'report', 'dead', 'explosion', 'moscow', 'busiest', 'airport']
# ['ijsmblog', 'week', 'apple', 'future', 'steve', 'job']
# ['low', 'fat', 'recipe', 'lunchbox', 'idea', 'diet', 'plan', 'dinner', 'tonight']
# ['happy', 'changed', 'headline', 'egyptian', 'protester', 'attack', 'foreign', 'journalist', 'prejudicial']
# ['madwrite', 'acai', 'berry', 'colon', 'cleansing', 'diet', 'visit', 'post', 'acai', 'fruit', 'deto']
# ['scholarship', 'advice', 'inside', 'financial', 'aid', 'office', 'college', 'planning', 'help']
# ['nobel', 'peace', 'prize', 'nomination', 'wikileaks', 'founder']
# ['comment', 'horse', 'racing', 'tip', 'free', 'daily', 'thoroughbred', 'tag', 'betting', 'tip', 'delta', 'down', 'fairground']
# ['deutsche', 'welle', 'yemen', 'unsettled', 'president', 'vow', 'relinquish', 'power']
# ['tsa', 'body', 'scanner', 'spot', 'bomb', 'dong', 'tsa']
# ['post', 'tsa', 'facing', 'lawsuit', 'governor', 'ventura', 'atomstack', 'big', 'si', 'fascism', 'tsa']
# ['australia', 'brace', 'flood', 'giant', 'inland', 'sea', 'floodwater', 'will', 'spread', 'australian', 'state', 'vi']
# ['king', 'speech', 'reign', 'producer', 'guild', 'award', 'news', 'india', 'stock']
# ['sag', 'award', 'recap', 'king', 'speech', 'conquers', 'king', 'town', 'king', 'speech', 'recogn', 'dating']
# ['check', 'fish', 'report', 'fishmyrtlebeach']
# ['virtual', 'master', 'real', 'brings', 'augmented', 'reality', 'fishing', 'hand', 'chris', 'scott', 'barrfishing', 'nice']
# ['reel', 'augmented', 'reality', 'fish', 'human', 'takara', 'tomy', 'fishing', 'reel', 'augmented', 'reality']
# ['guess', 'calling', 'beef', 'burrito', 'beef', 'burrito', 'gross']
# ['riz', 'khan', 'arizona', 'immigration', 'law']
# ['tsa', 'testing', 'advanced', 'imaging', 'technology', 'story', 'atlanta', 'tsa', 'tuesday', 'testing']
# ['colinfirth', 'nominated', 'oscar', 'best', 'actor', 'role', 'kingsspeech']
# ['national', 'summit', 'address', 'bedbug', 'epidemic']
# ['antonin', 'scalia', 'charm', 'tea', 'party', 'caucus', 'simmi', 'aujla', 'politico']
# ['singapore', 'news', 'somali', 'pirate', 'face', 'prosecution', 'malaysia', 'kuala', 'lumpur', 'somali', 'pirate', 'captured']
# ['parent', 'feel', 'helpless', 'bully', 'picking', 'kid', 'tip', 'bully', 'proofing', 'child']
# ['court', 'emanuel', 'eligible', 'chicago', 'mayor']
# ['oscar', 'nomination', 'king', 'speech', 'nomination', 'actor', 'colin', 'firth', 'helena', 'bonham', 'carter', 'geoffrey', 'rush']
# ['share', 'bass', 'fishing', 'fayetteville']
# ['blackswan', 'night', 'amazing', 'natalie', 'portman', 'will', 'win', 'oscar', 'performance']
# ['al', 'gore', 'explains', 'snowmaggedon', 'midst', 'global', 'warming', 'matt', 'harding', 'global', 'warming', 'guru', 'vice']
# ['christina', 'aguilera', 'explains', 'national', 'anthem', 'flub', 'movie', 'tv', 'caught']
# ['pro', 'fisherman', 'season', 'shop', 'learn', 'tip', 'great', 'guy', 'help', 'teach', 'fish', 'skar']
# ['celtic', 'marquis', 'daniel', 'leaf', 'game', 'stretcher']
# ['bull', 'parent', 'educator', 'guide', 'cyber', 'bullying', 'facebook', 'twitter', 'like', 'changing', 'lif']
# ['watching', 'material', 'keeping', 'kardashians', 'lol', 'love']
# ['australian', 'open', 'grand', 'slam', 'final', 'live', 'djokovic', 'win', 'rmang']
# ['phd', 'position', 'biophysical', 'chemistry', 'lund', 'university', 'sweden', 'beasiswa', 'scholarship']
# ['volkswagen', 'commercial', 'force', 'best', 'commercial', 'darthvader', 'passat']
# ['gear', 'salmon', 'fishing']
# ['record', 'snowstorm', 'indicator', 'global', 'warming']
# ['acai', 'berry', 'capsule', 'review', 'acai', 'berry', 'benefit', 'letspost', 'jone', 'dow', 'acai', 'berry', 'capsule', 'well']
# ['news', 'release', 'high', 'school', 'student', 'apply', 'scholarship', 'novec', 'electric', 'cooperative']
# ['rahm', 'chicago', 'economy', 'raised', 'tax', 'deserve']
# ['protest', 'start', 'yemen', 'despite', 'concession', 'president', 'hundred', 'anti', 'government', 'protest']
# ['lake', 'shore', 'drive', 'closed', 'chicago', 'blizzard']
# ['advertising', 'social', 'medium', 'technique', 'combine', 'super', 'bowl', 'tv', 'commercial']
# ['md', 'striped', 'bass', 'fishing', 'season', 'early']
# ['nfl', 'concussion', 'news', 'goodell', 'order', 'super', 'bowl', 'played', 'hand', 'touch']
# ['tennis', 'murray', 'crushed', 'djokovic', 'awesomeness', 'murray', 'clinch', 'st', 'break', 'point', 'hope', 'alive']
# ['acai', 'berry', 'weight', 'loss', 'diet', 'plan', 'healthy', 'weight', 'reduction', 'number', 'diet', 'plan']
# ['budwieser', 'commercial', 'tiny', 'dancer', 'hate', 'superbowl']
# ['healthy', 'super', 'bowl', 'snack', 'superbowl', 'recipe']
# ['elizabeth', 'olsen', 'sundance', 'breakout', 'star', 'elizabeth', 'olsen', 'hit', 'premiere', 'movie', 'martha', 'marcy', 'marl']
# ['madwrite', 'weight', 'loss', 'minimal', 'technique', 'numerous', 'acai', 'berry', 'pulp', 'diet', 'benefit', 'leave', 'conse']
# ['king', 'speech', 'win', 'top', 'director', 'british', 'movie', 'king', 'speech', 'awarded', 'top', 'honour', 'year', 'direct']
# ['join', 'yemen', 'day', 'rage']
# ['mass', 'rally', 'yemen', 'day', 'rage', 'anti', 'government', 'protester', 'gather', 'yemen', 'capital', 'sanaa', 'day', 'rage']
# ['invest', 'stock', 'market', 'money', 'rich', 'investment', 'advice']
# ['joanna', 'yeates', 'suspect', 'court', 'img']
# ['cold', 'water', 'aquarium', 'fish', 'water', 'temperature', 'factor', 'consider', 'choosing', 'fish']
# ['john', 'salley', 'sundance']
# ['signed', 'pledge', 'will', 'text', 'drive', 'awsome', 'orange', 'thumb', 'ring']
# ['count', 'jesse', 'ventura', 'flier', 'don', 'junk', 'touched', 'transportation', 'security', 'administration', 'agent']
# ['great', 'commercial', 'superbowl', 'audi', 'pretty', 'good', 'jab', 'mercedes']
# ['sodahead', 'state', 'inspired', 'arizona', 'illegal', 'immigration', 'law', 'face', 'tough', 'fiscal', 'reality', 'state', 'iowa']
# ['condemns', 'attack', 'journalist', 'egypt', 'ap', 'ap', 'white', 'house', 'spokesman', 'robert', 'gibbs', 'systematic']
# ['deadly', 'blast', 'moscow', 'airport']
# ['love', 'hate', 'crime', 'pepsi', 'max', 'commercial', 'lol', 'nice', 'superbowl']
# ['dead', 'moscow', 'airport', 'explosion', 'cnn']
# ['desire', 'freedom', 'infectious', 'thousand', 'protest', 'jordan', 'middle', 'east', 'al', 'jazeera', 'english']
# ['face', 'chrysler', 'commercial', 'freaked', 'best', 'superbowl', 'lt']
# ['dont', 'imma', 'kourtney', 'kim', 'khloe', 'fave', 'interested']
# ['social', 'medium', 'marketing', 'medical', 'field', 'facebook', 'privacy', 'hcsm']
# ['financial', 'aid', 'low', 'income', 'student', 'sdut']
# ['wing', 'healthy', 'oven', 'fried', 'wing', 'drip', 'pan', 'fat', 'drain']
# ['chamber', 'commerce', 'writes', 'iran', 'express', 'opposition', 'sanction', 'capital', 'loyalty', 'homeland']
# ['alex', 'brown']
# ['love', 'good', 'upcycle', 'starbucks', 'terrifying', 'trenta', 'cup', 'hold', 'entire', 'bottle', 'wine']
# ['best', 'ad', 'super', 'bowl', 'darth', 'vader', 'passat', 'commercial']
# ['real', 'life', 'murder', 'freaked', 'dutch', 'man', 'killer', 'gt']
# ['caught', 'lb', 'blue', 'marlin', 'flick', 'fishing', 'flickfishing']
# ['giffords', 'husband', 'great', 'rep', 'gabrielle', 'giffords', 'ariz', 'adjusting', 'rehabili']
# ['christina', 'aguilera', 'screwed', 'forgot', 'national', 'anthem', 'american', 'event', 'deporther', 'fail', 'fb']
# ['ap', 'journalist', 'attacked', 'mob', 'detained', 'cairo', 'damn', 'liberal', 'medium', 'front', 'line', 'history']
# ['movie', 'nod', 'king', 'speech', 'stir', 'oscar', 'race', 'factbox', 'gt', 'news', 'race']
# ['al', 'jazeera', 'english', 'journalist', 'released', 'detained', 'equipment', 'held']
# ['dont', 'text', 'drive', 'safe', 'life', 'safe', 'yourselfs']
# ['aje', 'human', 'shield', 'national', 'museum', 'arrested', 'looter', 'damage', 'jan', 'egypt', 'reggaala']
# ['wanting', 'fish', 'chesapeake', 'checkout', 'virginia', 'beach', 'fishing', 'charter', 'good', 'ad']
# ['neddesmond', 'posted', 'fishing', 'pic', 'tuesday', 'quiz', 'specie', 'gofishn']
# ['identity', 'theft', 'social', 'security', 'number']
# ['jesse', 'ventura', 'slam', 'tsa', 'lawsuit', 'count', 'jesse', 'ventura', 'flier', 'don', 'junk', 'touched', 'tr']
# ['love', 'kardashian']
# ['jay', 'carney', 'white', 'house', 'press', 'secretary', 'richard', 'adam', 'guardian']
# ['winter', 'storm', 'hit', 'harder', 'chicago', 'toronto']
# ['great', 'commercial', 'vw', 'america', 'video', 'volkswagen', 'passat', 'super', 'bowl', 'xlv', 'commercial']
# ['weekend', 'wrap', 'king', 'speech', 'rule', 'sag', 'dgas', 'portman', 'pick', 'trophy', 'weekend']
# ['carp', 'carp', 'fishing', 'carp', 'fishing', 'usualy', 'involves', 'ultra', 'light', 'rig', 'lb', 'test', 'small', 'tr']
# ['pro', 'democracy', 'protest', 'break', 'jordan', 'catspirit']
# ['health', 'care', 'law', 'struck', 'federal', 'judge', 'ruled', 'president', 'obama', 'sweeping', 'health']
# ['fishing', 'find', 'fly', 'tying', 'material', 'tool', 'cheap', 'ebay', 'info']
# ['fast', 'black', 'beetle']
# ['youtube', 'video', 'sauna', 'doritos', 'superbowl', 'commercial', 'ad']
# ['thousand', 'protesting', 'jordan', 'demanding', 'govt', 'step']
# ['filler', 'starbucks', 'trenta', 'cup', 'hold', 'entire', 'bottle', 'wine']
# ['type', 'fishing', 'rod']
# ['photo', 'sundance', 'film', 'festival', 'star', 'park', 'city', 'utah']
# ['sport', 'super', 'bowl', 'xlv', 'christina', 'aguilera', 'repeat', 'national', 'anthem', 'christina', 'aguilera', 'smokinsession']
# ['penalty', 'law', 'biased', 'favor', 'bullying', 'school', 'workplace', 'issue']
# ['moscow', 'airport', 'blast', 'dozen', 'killed', 'explosion', 'hit', 'domodedovo', 'airport', 'early', 'unconfirmed', 'report']
# ['revenge', 'pug', 'doritos', 'nailed', 'super', 'bowl', 'commercial']
# ['oscar', 'nominee', 'academy', 'award']
# ['list', 'journalist', 'beaten', 'jailed', 'missing']
# ['fishing', 'report', 'jetty', 'beach', 'good', 'weather', 'brought', 'handful', 'surf', 'fishe']
# ['darth', 'vader', 'volkswagen', 'commercial', 'best', 'super', 'bowl', 'commercial', 'youtube']
# ['boston', 'celtic', 'kendrick', 'perkins', 'play', 'cleveland', 'cavalier', 'ad']
# ['medical', 'news', 'giffords', 'cleared', 'rehab', 'critical', 'care', 'head', 'trauma', 'medpage', 'today']
# ['half', 'men', 'charlie', 'sheen', 'lost', 'teeth']
# ['missouri', 'fly', 'fishing', 'website']
# ['cook', 'seared', 'chicken', 'apricot', 'sauce', 'chili', 'rubbed', 'steak', 'pan', 'salsa']
# ['urban', 'gossip', 'iphone', 'app', 'event', 'fab', 'ybf', 'celebs', 'hit', 'sundance', 'film', 'festival', 'yb', 'africanamerican']
# ['tx', 'fishing', 'news', 'coolfishing', 'day', 'guna', 'fishing']
# ['goodbye', 'pound', 'acai', 'berry', 'weight', 'loss', 'pill', 'acai', 'ultima', 'making', 'larg']
# ['employment', 'gaining', 'speed', 'jobless', 'rate', 'washington', 'reuters', 'employment', 'shifted']
# ['watching', 'rite', 'therite']
# ['anti', 'government', 'rally', 'yemen', 'stay', 'calm']
# ['acai', 'berry', 'weight', 'loss', 'diet', 'plan', 'healthy', 'weight', 'reduction']
# ['watching', 'extreme', 'makeover', 'edition', 'sad', 'story', 'texting', 'driving', 'text', 'drive']
# ['favorite', 'kardashian', 'love', 'khloe']
# ['djokovic', 'murray', 'australian', 'open', 'title', 'ap']
# ['kaufmann', 'streamborn', 'northwest', 'fly', 'fishing', 'blog', 'st', 'steelhead']
# ['sedative', 'help', 'free', 'whale', 'fishing', 'whale', 'oceanshash', 'sedative', 'help']
# ['ynet', 'egypt', 'police', 'target', 'reporter', 'israel']
# ['view', 'detriot', 'chrysler', 'superbowl', 'commercial']
# ['michelle', 'obama', 'visit', 'army', 'find', 'whip', 'couch', 'potato', 'shape']
# ['djokovic', 'murray', 'australian', 'open', 'final', 'interesting', 'match', 'novak']
# ['fantastic', 'wonderful']
# ['pre', 'empting', 'mass', 'anti', 'government', 'protest', 'ali', 'saleh', 'vow', 'seek', 'extension', 'pas', 'rein']
# ['suffering', 'bad', 'credit', 'history', 'bad', 'credit', 'debt', 'consolidation', 'loan', 'pay', 'debt']
# ['superbowl', 'sucked', 'pepsi', 'max', 'commercial', 'prob', 'best']
# ['christina', 'aguilera', 'national', 'anthem', 'politicsthe', 'votechristina', 'aguilera', 'national', 'anthem', 'flubbed', 'itth']
# ['watch', 'chevrolet', 'commercial', 'superbowl']
# ['ultimate', 'chicken', 'soup']
# ['good', 'set', 'fish', 'stock', 'cleaned', 'ich', 'tank', 'fish', 'today', 'community', 'tank']
# ['live', 'moscow', 'airport', 'explosion']
# ['supreme', 'court', 'refuse', 'reinstate', 'circuit', 'global', 'warming', 'case']
# ['yemeni', 'protester', 'urged', 'president', 'ali', 'abdullah', 'saleh', 'step', 'muhammadjusuf']
# ['indian', 'navy', 'coast', 'guard', 'rescue', 'thai', 'vessel', 'pirate', 'joint', 'operation', 'indian', 'navy', 'coast', 'guard', 'intercepted', 'neutr']
# ['christie', 'prof', 'adept', 'social', 'medium']
# [['crispi', 'chicken', 'drumstick', 'ranch', 'dress', 'recip'], ['don', 'fda', 'approv', 'ingredi', 'list', 'taco', 'bell', 'beef']]

# %% [markdown]
# ## 得到文本的tf-idf矩阵

# %%
vectorizer=CountVectorizer()#该类会将文本中的词语转换为词频矩阵，矩阵元素a[i][j] 表示j词在i类文本下的词频  
transformer=TfidfTransformer()#该类会统计每个词语的tf-idf权值

# %%
tfidf=transformer.fit_transform(vectorizer.fit_transform(text)) #第一个fit_transform是计算tf-idf，第二个fit_transform是将文本转为词频矩阵
weight=tfidf.toarray()   #将tf-idf矩阵抽取出来，元素a[i][j]表示j词在i类文本中的tf-idf权重 
vocab=vectorizer.get_feature_names()#获取词袋模型中的所有词
print(vocab[:10])
# Out:
# ['aacons', 'aaron', 'aaup', 'aba', 'abby', 'abc', 'abdallah', 'abdullah', 'abel', 'absence']

# %%
weight.shape
# Out:
# (2472, 5097)

# %% [markdown]
# ## 尝试各聚类方法

# %% [markdown]
# ### KMeans

# %%
mykms=KMeans(n_clusters=max(label))
y1=mykms.fit_predict(weight)

# %%
mykms2=MiniBatchKMeans(n_clusters=max(label))
y2=mykms2.fit_predict(weight)

# %% [markdown]
# ###  AffinityPropagation

# %%
mykms3=AffinityPropagation()
y3=mykms3.fit_predict(weight)

# %% [markdown]
# ### MeanShift

# %%
mykms4=MeanShift(bandwidth=0.4,min_bin_freq=2)
y4=mykms4.fit_predict(weight)

# %% [markdown]
# ### SpectralClustering

# %%
mykms5=SpectralClustering(n_clusters=max(label))
y5=mykms5.fit_predict(weight)

# %% [markdown]
# ### Ward hierarchical clustering

# %%
mykms6=AgglomerativeClustering(n_clusters=max(label))
y6=mykms6.fit_predict(weight)

# %% [markdown]
# ### AgglomerativeClustering

# %%
mykms7=AgglomerativeClustering(n_clusters=max(label),linkage ='average')
y7=mykms7.fit_predict(weight)

# %% [markdown]
# ### DBSCAN

# %%
mykms8=DBSCAN(eps=0.7, min_samples=1)
y8=mykms8.fit_predict(weight)

# %% [markdown]
# ### GaussianMixture

# %%
mykms9=GaussianMixture(n_components=11)
y9=mykms9.fit_predict(weight)

# %% [markdown]
# ## NMI评价（按上述方法顺序依次排列）

# %%
NMI(label,y1)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.8025938826711199

# %%
NMI(label,y2)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.6607457455387594

# %%
NMI(label,y3)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.7831643850554082

# %%
NMI(label,y4)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.6994805035385545

# %%
NMI(label,y5)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.680920890243362

# %%
NMI(label,y6)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.77587403569932

# %%
NMI(label,y7)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.9004539868135747

# %%
NMI(label,y8)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.706878988031472

# %%
NMI(label,y9)
# Out:
# G:\anaconda3\envs\python35\lib\site-packages\sklearn\metrics\cluster\supervised.py:844: FutureWarning: The behavior of NMI will change in version 0.22. To match the behavior of 'v_measure_score', NMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.613721759544673
